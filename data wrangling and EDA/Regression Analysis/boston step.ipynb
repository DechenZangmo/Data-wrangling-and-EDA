# %% [markdown]
# ### 1.Load Liabrories
# ### 2.Read.CSV(File)
# ### 3.head/tail/size/shape/info->categories
#                                  b.missing value
#                                  c.out liers
# ### 4.Describe()-> skewed or not
# ### 5.Data Exploration->Histogram
#                        b.bar plot
#                        c.pair plot/corrmatrix/heatmap
#                        d.latitude/longitude/map
# ### 6.missing value:
#                      a.zero
#                      b.Act
#                      c.drop
#                      d.mean
#                      e.median
#                      f.mode
#                      g.series data:
#                            1.backfill
#                            2.forwardfill
# ### 7.Categiries:
#                  1.Nominal=>one-hot-en(acting->get_dumies)
#                   2.ordinal-Factorization
# ### 8.Outliers-:
#                 1.choose 1 col
#                 2.count of lower and upper outliers
#                 3.plot box plot
#                 4.IQR methode for all col
# ### 9.Normalized/Standazi data/Exclude label or target col
#  1.minmaxscaling   z-score
# * 1.input and output->supervised-
#                                  1. cat->classification
#                                  2.conti->REgression
# ### 10.
#       x scaled
#        y
#
# ### 11.Bifrucation:
#                    1.label->cat->stratified
#                    2.label-> cont->simple random
#         x_train/ x_test/y_train/y_test
#
# ### 12.import model
# ### 13.model instantiation
# ### 14.fit model with train data(x_train,y_train)
# ### 15.model predict(x_test)=y predicted
# ### 16.performance measures:
#                           a.MAE
#                           b.RMSE
#                           c.R2
#                           d.adj.R2
#
#
# ### 17.
#         R2-train
#         R2-test/ VIF=multicalinearity:
#                          1. underfiting   2. overfiting
#                          ->change algo        ->cross validation with grid search cv
#                                                 3. Ridge/lasso/elastic net
#                                                 r2-train
#                                                 r2-test
#                                                 4.cross validation with grid search cv
#                                                 5.take optimized parameter
#                                                 6. but back to algo
#                                                 7.get finest R2 val
#                                                 8.predict for new data

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Boston_housing.data',delim_whitespace=True)
df
# Out:
#      0.00632  18.00  2.310  0  0.5380  6.5750  65.20  4.0900  1  296.0  15.30  \
# 0    0.02731    0.0   7.07  0   0.469   6.421   78.9  4.9671  2  242.0   17.8
# 1    0.02729    0.0   7.07  0   0.469   7.185   61.1  4.9671  2  242.0   17.8
# 2    0.03237    0.0   2.18  0   0.458   6.998   45.8  6.0622  3  222.0   18.7
# 3    0.06905    0.0   2.18  0   0.458   7.147   54.2  6.0622  3  222.0   18.7
# 4    0.02985    0.0   2.18  0   0.458   6.430   58.7  6.0622  3  222.0   18.7
# ..       ...    ...    ... ..     ...     ...    ...     ... ..    ...    ...
# 500  0.06263    0.0  11.93  0   0.573   6.593   69.1  2.4786  1  273.0   21.0
# 501  0.04527    0.0  11.93  0   0.573   6.120   76.7  2.2875  1  273.0   21.0
# 502  0.06076    0.0  11.93  0   0.573   6.976   91.0  2.1675  1  273.0   21.0
# 503  0.10959    0.0  11.93  0   0.573   6.794   89.3  2.3889  1  273.0   21.0
# 504  0.04741    0.0  11.93  0   0.573   6.030   80.8  2.5050  1  273.0   21.0
#
#      396.90  4.98  24.00
# ...

# %%
df.head()
# Out:
#    0.00632  18.00  2.310  0  0.5380  6.5750  65.20  4.0900  1  296.0  15.30  \
# 0  0.02731    0.0   7.07  0   0.469   6.421   78.9  4.9671  2  242.0   17.8
# 1  0.02729    0.0   7.07  0   0.469   7.185   61.1  4.9671  2  242.0   17.8
# 2  0.03237    0.0   2.18  0   0.458   6.998   45.8  6.0622  3  222.0   18.7
# 3  0.06905    0.0   2.18  0   0.458   7.147   54.2  6.0622  3  222.0   18.7
# 4  0.02985    0.0   2.18  0   0.458   6.430   58.7  6.0622  3  222.0   18.7
#
#    396.90  4.98  24.00
# 0  396.90  9.14   21.6
# 1  392.83  4.03   34.7
# 2  394.63  2.94   33.4
# 3  396.90  5.33   36.2
# 4  394.12  5.21   28.7

# %%
df.tail()
# Out:
#      0.00632  18.00  2.310  0  0.5380  6.5750  65.20  4.0900  1  296.0  15.30  \
# 500  0.06263    0.0  11.93  0   0.573   6.593   69.1  2.4786  1  273.0   21.0
# 501  0.04527    0.0  11.93  0   0.573   6.120   76.7  2.2875  1  273.0   21.0
# 502  0.06076    0.0  11.93  0   0.573   6.976   91.0  2.1675  1  273.0   21.0
# 503  0.10959    0.0  11.93  0   0.573   6.794   89.3  2.3889  1  273.0   21.0
# 504  0.04741    0.0  11.93  0   0.573   6.030   80.8  2.5050  1  273.0   21.0
#
#      396.90  4.98  24.00
# 500  391.99  9.67   22.4
# 501  396.90  9.08   20.6
# 502  396.90  5.64   23.9
# 503  393.45  6.48   22.0
# 504  396.90  7.88   11.9

# %%
df.shape
# Out:
# (505, 14)

# %%
df.size
# Out:
# 7070

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   0.00632  505 non-null    float64
#  1   18.00    505 non-null    float64
#  2   2.310    505 non-null    float64
#  3   0        505 non-null    int64
#  4   0.5380   505 non-null    float64
#  5   6.5750   505 non-null    float64
#  6   65.20    505 non-null    float64
#  7   4.0900   505 non-null    float64
#  8   1        505 non-null    int64
#  9   296.0    505 non-null    float64
#  10  15.30    505 non-null    float64
#  11  396.90   505 non-null    float64
#  12  4.98     505 non-null    float64
#  13  24.00    505 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.4 KB

# %%
df.describe()
# Out:
#           0.00632       18.00       2.310           0      0.5380      6.5750  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean     3.620667   11.350495   11.154257    0.069307    0.554728    6.284059
# std      8.608572   23.343704    6.855868    0.254227    0.115990    0.703195
# min      0.009060    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082210    0.000000    5.190000    0.000000    0.449000    5.885000
# 50%      0.259150    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.678220   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#             65.20      4.0900           1       296.0       15.30      396.90  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean    68.581584    3.794459    9.566337  408.459406   18.461782  356.594376
# ...

# %%
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
df.corr()
# Out:
#           0.00632     18.00     2.310         0    0.5380    6.5750     65.20  \
# 0.00632  1.000000 -0.200283  0.406251 -0.056132  0.420934 -0.218978  0.352701
# 18.00   -0.200283  1.000000 -0.534022 -0.042550 -0.516574  0.311835 -0.569524
# 2.310    0.406251 -0.534022  1.000000  0.062350  0.764556 -0.391330  0.645543
# 0       -0.056132 -0.042550  0.062350  1.000000  0.091134  0.091497  0.086461
# 0.5380   0.420934 -0.516574  0.764556  0.091134  1.000000 -0.302127  0.731461
# 6.5750  -0.218978  0.311835 -0.391330  0.091497 -0.302127  1.000000 -0.240211
# 65.20    0.352701 -0.569524  0.645543  0.086461  0.731461 -0.240211  1.000000
# 4.0900  -0.379627  0.664395 -0.708848 -0.099109 -0.769221  0.205170 -0.747872
# 1        0.625396 -0.311717  0.594167 -0.007907  0.611758 -0.209277  0.456232
# 296.0    0.582568 -0.314351  0.720561 -0.035965  0.668141 -0.291680  0.506527
# 15.30    0.289394 -0.391713  0.380955 -0.122570  0.188918 -0.355116  0.261724
# ...

# %%
import matplotlib.pyplot as pl
import seaborn as sns

# %%
plt.figure(figsize=(14,14))
sns.heatmap(df.corr(), annot=True, fmt=".2f")
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
col_name=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']

# %%
df.columns=col_name

# %%
x = df[['LSTAT','RM']].values
y = df['MEDV'].values
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2,random_state=40)
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
ypr = model.predict(x_test)
yp = model.predict(x_train)
from sklearn.metrics import mean_absolute_error
from statsmodels.tools.eval_measures import rmse
MAE = mean_absolute_error(y_test, ypr)
RMSE = rmse(y_test, ypr)
print('MAE =',MAE,'\nRMSE =',RMSE)
# Out:
# MAE = 4.318228762416102
# RMSE = 5.9788391110481784

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,ypr)
# Out:
# 0.6641709194108967

# %%
r2_score(y_train,yp)
# Out:
# 0.6294174066975879

# %%
X=df[['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']]
from statsmodels.stats.outliers_influence import variance_inflation_factor
#VIF dataframe
Vif_data=pd.DataFrame()
Vif_data['feature']=X.columns
#calculating VIF for each feature
Vif_data["VIF"]=[variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
print(Vif_data)
# Out:
#     feature         VIF
# 0      CRIM    2.131627
# 1        ZN    2.907483
# 2     INDUS   14.582330
# 3      CHAS    1.176321
# 4       NOX   74.044961
# 5        RM  135.863175
# 6       AGE   21.374247
# 7       DIS   15.406800
# 8       RAD   15.421360
# 9       TAX   62.083006
# 10  PTRATIO   87.203774
# 11        B   21.308387
# 12    LSTAT   12.645549
# 13     MEDV   24.509057
