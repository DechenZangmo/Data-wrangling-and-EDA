# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Boston_housing.data', delim_whitespace=True)
df
# Out:
#      0.00632  18.00  2.310  0  0.5380  6.5750  65.20  4.0900  1  296.0  15.30  \
# 0    0.02731    0.0   7.07  0   0.469   6.421   78.9  4.9671  2  242.0   17.8
# 1    0.02729    0.0   7.07  0   0.469   7.185   61.1  4.9671  2  242.0   17.8
# 2    0.03237    0.0   2.18  0   0.458   6.998   45.8  6.0622  3  222.0   18.7
# 3    0.06905    0.0   2.18  0   0.458   7.147   54.2  6.0622  3  222.0   18.7
# 4    0.02985    0.0   2.18  0   0.458   6.430   58.7  6.0622  3  222.0   18.7
# ..       ...    ...    ... ..     ...     ...    ...     ... ..    ...    ...
# 500  0.06263    0.0  11.93  0   0.573   6.593   69.1  2.4786  1  273.0   21.0
# 501  0.04527    0.0  11.93  0   0.573   6.120   76.7  2.2875  1  273.0   21.0
# 502  0.06076    0.0  11.93  0   0.573   6.976   91.0  2.1675  1  273.0   21.0
# 503  0.10959    0.0  11.93  0   0.573   6.794   89.3  2.3889  1  273.0   21.0
# 504  0.04741    0.0  11.93  0   0.573   6.030   80.8  2.5050  1  273.0   21.0
#
#      396.90  4.98  24.00
# ...

# %%
col_name=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']

# %%
df.columns=col_name

# %%
df.head()
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0  0.02731  0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0     17.8
# 1  0.02729  0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0     17.8
# 2  0.03237  0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0     18.7
# 3  0.06905  0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0     18.7
# 4  0.02985  0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222.0     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   9.14  21.6
# 1  392.83   4.03  34.7
# 2  394.63   2.94  33.4
# 3  396.90   5.33  36.2
# 4  394.12   5.21  28.7

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean     3.620667   11.350495   11.154257    0.069307    0.554728    6.284059
# std      8.608572   23.343704    6.855868    0.254227    0.115990    0.703195
# min      0.009060    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082210    0.000000    5.190000    0.000000    0.449000    5.885000
# 50%      0.259150    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.678220   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean    68.581584    3.794459    9.566337  408.459406   18.461782  356.594376
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200283  0.406251 -0.056132  0.420934 -0.218978  0.352701
# ZN      -0.200283  1.000000 -0.534022 -0.042550 -0.516574  0.311835 -0.569524
# INDUS    0.406251 -0.534022  1.000000  0.062350  0.764556 -0.391330  0.645543
# CHAS    -0.056132 -0.042550  0.062350  1.000000  0.091134  0.091497  0.086461
# NOX      0.420934 -0.516574  0.764556  0.091134  1.000000 -0.302127  0.731461
# RM      -0.218978  0.311835 -0.391330  0.091497 -0.302127  1.000000 -0.240211
# AGE      0.352701 -0.569524  0.645543  0.086461  0.731461 -0.240211  1.000000
# DIS     -0.379627  0.664395 -0.708848 -0.099109 -0.769221  0.205170 -0.747872
# RAD      0.625396 -0.311717  0.594167 -0.007907  0.611758 -0.209277  0.456232
# TAX      0.582568 -0.314351  0.720561 -0.035965  0.668141 -0.291680  0.506527
# PTRATIO  0.289394 -0.391713  0.380955 -0.122570  0.188918 -0.355116  0.261724
# ...

# %%
import matplotlib.pyplot as pl
import seaborn as sns

# %%
plt.figure(figsize=(14,14))
sns.heatmap(df.corr(), annot=True, fmt=".2f")
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('MEDV',axis=1)
y=df['MEDV']

X_train,X_test,y_train,y_test =train_test_split(x,y,test_size=0.3,random_state=0)

# %% [markdown]
# import model
# instantiate model
# train model(train data)
# test model(test data)
# predict with new data

# %%
X_train.shape
# Out:
# (353, 13)

# %%
from sklearn.linear_model import LinearRegression
#step 2 instantiate the model
model = LinearRegression()
#step 3 fit thr train data with model
model.fit(X_train,y_train)
# step 4 test the model with test data
y_test_pred = model.predict(x_test)
#step 5 predict for new data
# model.predict(["list of column values"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 7
#       5 model.fit(X_train,y_train)
#       6 # step 4 test the model with test data
# ----> 7 y_test_pred = model.predict(x_test)
#
# NameError: name 'x_test' is not defined

# %% [markdown]
# ## supervised regression analysis
# =>regression analysis is understand relation between your input and output
# ### linear equation
# relation between  variable
# eg: y=mx+c+error
# y=output
# x=input
# m= slope
# ### best fit line
# ### how to stablished best fit line?
# =>using ordinary least method

# %% [markdown]
# ### what is R-square
# values is a stat
# distance actual mean
#    vs
# distance predicted mean

# %% [markdown]
# ### Linear regression with Scikit-Learn

# %%
df.head()

# %%
x=df["RM"].values.reshape(-1,1)

# %%
y=df["MEDV"].values

# %% [markdown]
# ### 1.import model

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### 2.instantiate model

# %%
model = LinearRegression()

# %% [markdown]
# ### 3.Model fit

# %%
model.fit(x,y)

# %%
model.coef_

# %%
model.intercept_

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 4. model predict(test)

# %%
model.predict(np.array([15]).reshape(1,-1))

# %%
plt.figure(figsize=(12,8));
sns.regplot(x=x,y=y);
plt.xlabel("average number of rooms per dwelling")
plt.ylabel("Median value of owner occupied homes in $1000's")
plt.show()

# %%
x=df["LSTAT"].values.reshape(-1,1)

# %%
y=df["MEDV"].values

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x,y)

# %%
model.coef_

# %%
model.intercept_

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
model.predict(np.array([15]).reshape(1,-1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 model.predict(np.array([15]).reshape(1,-1))
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:369, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
#     367     check_is_fitted(self)
# --> 369     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
plt.figure(figsize=(12,8));
sns.regplot(x=x,y=y);
plt.xlabel("average number of rooms per dwelling")
plt.ylabel("Median value of owner occupied homes in $1000's")
plt.show()

# %% [markdown]
# ### 5.find performance measured

# %% [markdown]
# ## Method 2:Mean Squared Error(MSE)

# %%
x=df["RM"].values.reshape(-1,1)

# %%
y=df["MEDV"].values

# %% [markdown]
# ### 2.Bifruciation into train and test

# %% [markdown]
# ### 3.import train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=40)

# %% [markdown]
# ### 4.import model

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### 5. instantiate model

# %%
LR = LinearRegression()

# %%
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
LR.coef_
# Out:
# array([-1.04875995e-01,  4.10314619e-02,  4.03485779e-02,  1.70049496e+00,
#        -1.86965468e+01,  3.75877021e+00,  6.69138390e-03, -1.40724572e+00,
#         3.16602760e-01, -1.37754579e-02, -9.97454129e-01,  5.64560618e-03,
#        -5.50193323e-01])

# %%
LR.intercept_
# Out:
# 39.351771378358706

# %%
LR.predict(X_test)
# Out:
# array([18.73597595, 34.5553619 , 17.3493922 , 19.06450005, 18.14176087,
#        33.49139066, 33.03796906, 13.10125416, 20.00907148, 10.2078418 ,
#        22.17391466, 14.89084854, -0.09900008,  4.79606715, 20.99186059,
#        39.96195701, 30.61384968, 18.7260974 , 17.19553105, 16.28742023,
#        39.3580136 , 12.56709842, 43.29764264, 25.01523717, 37.82577731,
#        29.87197803, 24.54889256, 15.60542179, 13.44992957, 19.13304414,
#        22.87581227, 27.74964206, 25.29541006, 21.44832952, 24.8923701 ,
#        23.10027363, 24.59554297,  2.92760633, 34.40764021, 29.87719894,
#        22.55506452,  7.83183802, 20.48835103, 24.88763302, 29.51554873,
#         5.48311215, 17.60145675, 40.60913355, 31.59096897, 41.05110645,
#         3.31546518, 19.49221522, 26.82245214,  7.67751962, 15.09384466,
#        25.00029048, 27.09427807, 31.21835709, 21.26110988,  9.3836291 ,
#        22.15149925, 13.99767934, 34.57105222, 13.5561001 , 26.51507873,
# ...

# %%
y_pred = LR.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 25.33420284601607

# %%
from sklearn.metrics import r2_score
y_train_pred=LR.predict(X_train)

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.7312779859745432

# %%
x=df["LSTAT"].values.reshape(-1,1)
y=df['MEDV']

# %%
from sklearn.linear_model import LinearRegression

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %%
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
LR.coef_
# Out:
# array([-0.96117535])

# %%
LR.intercept_
# Out:
# 34.773142569471304

# %%
yp=LR.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,yp)
# Out:
# 121.27832055459153

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, yp)
# Out:
# -0.46500582323923223

# %% [markdown]
# # Assumption of linear regression

# %% [markdown]
# ### There are 5 basic assumption of linear regression algorithm
# ### 1.Linear relationship between the features and target
#   =>
# ### 2.Little or no multicollinearity between the features
#   =>multicollinearity is a state of very high inter-correlations or inter-association among the independent variables.type of disturbance in the data present weaknes the statical power of the regression model.pair plots and heatmaps(correlation matrix)can be used for identify highly correlated features.
# ### 3. NO or low Heteroscedasticty
# =>errothm should not explain other error

# %%
# !pip install yellowbrick

# %%
from yellowbrick.regressor import ResidualsPlot

# %%
plot_visual = ResidualsPlot(LR)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
plot_visual.fit(x_train,y_train)
plot_visual.score(x_test,y_test)

plt.legend(loc="upper left")
plot_visual.show()
# Out:
# <Axes: title={'center': 'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# ### Normal distribution

# %%
plot_visuals=ResidualsPlot(LR,hist=False, qqplot=True)
plot_visuals.fit(X_train,y_train)
plot_visuals.score(X_test,y_test)
plot_visuals.show()
# Out:
# <Axes: title={'center': 'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# ### 5.LIttle or no autocorrelation in the residuals

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from statsmodels.tools.eval_measures import rmse
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)
RMSE=rmse(y_test,y_pred)
print('MAE=',MAE,'\nMSE=',MSE,'\nRMSE=',RMSE,'\nr2=',r2)
# Out:
# MAE= 9.665278895364946
# MSE= 156.31372536724592
# RMSE= 12.502548754843787
# r2= -0.8882230300357135
